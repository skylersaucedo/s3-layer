# %%
"""use notebook to ID all images with defects. Make sure bounding box coordinates exist. 

    then condition and send to API endpoint

"""
import os
import matplotlib.pyplot as plt
from PIL import Image
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd
import httpx

"""useful functions"""

def read_xml(xml_path):
    """Reads the XML file and extracts bounding box coordinates for all defects."""
    tree = ET.parse(xml_path)
    root = tree.getroot()
    defects = []
    for obj in root.findall("object"):
        name = obj.find("name").text
        xmin = int(obj.find("bndbox/xmin").text)
        ymin = int(obj.find("bndbox/ymin").text)
        xmax = int(obj.find("bndbox/xmax").text)
        ymax = int(obj.find("bndbox/ymax").text)
        defects.append((name, xmin, ymin, xmax, ymax))
    return defects

def plot_defects_on_image(image_path, xml_path):
    """Plots bounding boxes for all defects on the image."""
    image = Image.open(image_path)
    defects = read_xml(xml_path)

    plt.imshow(image)
    
    for name, xmin, ymin, xmax, ymax in defects:
        rect = plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                            linewidth=1, edgecolor="r", facecolor="none")
        plt.gca().add_patch(rect)
        plt.text(xmin, ymin, name, color="r", fontsize=8, backgroundcolor="white")

    plt.title(f"Defects in {os.path.basename(image_path)}")
    plt.axis("off")  # Hide axes
    plt.show()


def grab_defect_data(image_path, xml_path):

    defect_list = []

    """grabs bounding boxes info for all defects on the image for associated xml file."""
    image = Image.open(image_path)
    defects = read_xml(xml_path)

    h, w, c = np.shape(image)
    
    for name, xmin, ymin, xmax, ymax in defects:

        xmin_n = xmin/w
        xmax_n = xmax/w
        ymin_n = ymin/h
        ymax_n = ymax/h

        img_name = os.path.basename(image_path).split('/')[-1]
        defect_list.append([img_name, h, w, c, name, xmin_n, ymin_n, xmax_n, ymax_n])

    df = pd.DataFrame(data=defect_list, columns=['image_path', 'h', 'w', 'c', 'defect', 'xmin_n', 'ymin_n','xmax_n','ymax_n'])
    return df

# %%
#import httpx
#!pip install httpx

#API_ROOT = os.environ["API_ROOT"]

# %%
def upload_to_api(file_name, file_stream, file_mimetype):
    file_details_response = httpx.post(
        f"{API_ROOT}/dataset",
        files={"file": (file_name, file_stream, file_mimetype)},
        auth=(os.environ["API_KEY"], os.environ["API_SECRET"]),
        timeout=600.0,
    )

    file_details = file_details_response.json() 

    if file_details_response.status_code != 200:
        print("Something happened", file_details_response.status_code)

    return file_details["dataset_object_id"]


## make sure we dont upload twice!

def get_uploaded_files():
    list_response = httpx.get(
        f"{API_ROOT}/dataset",
        auth=(os.environ["API_KEY"], os.environ["API_SECRET"]),
    )

    json_response = list_response.json()

    return json_response["files"]

# %%
import mimetypes
mimetypes.init()
from hashlib import md5

# %%
import os

upload_count = 0
combined_folder = r"C:\Users\endle\Desktop\object-detection-pytorch-wandb-coco\data\combined"
df_f = pd.DataFrame(columns=['image_path', 'h', 'w', 'c', 'defect', 'xmin_n', 'ymin_n','xmax_n','ymax_n'])

for filename in os.listdir(combined_folder):
    print(filename)
    if filename.endswith(".bmp"):
        image_path = os.path.join(combined_folder, filename)
        xml_path = os.path.join(combined_folder, filename.replace(".bmp", ".xml"))

        # Check if the associated .xml file exists
        if os.path.exists(xml_path):


            #plot your defects on images here, double check overlay..its good.

            #plot_defects_on_image(image_path, xml_path)

            # defects stored as dataframe here
            df = grab_defect_data(image_path, xml_path)

            # # --- add image to API here -----
            # with open(image_path, "rb") as f:
            #     file_hash = md5(f.read()).hexdigest()

            #     file_mimetype = mimetypes.guess_type(image_path)[0]
            #     print(f"File mimetype: {file_mimetype}")
            #     file_guid = upload_to_api(image_path, f, file_mimetype)
            #     print(f"Uploaded {image_path} as {file_guid}")
            #     image_path.append(file_hash)
            #     upload_count += 1

            ## add json bounding box info

            # combine final dataframe

            df_f = pd.concat([df_f, df],ignore_index=True )



        else:
            print(f"Skipping {filename}: No associated .xml file found.")

print("Defect plots generated successfully!")
# Out:
# 0.bmp
# Skipping 0.bmp: No associated .xml file found.
# 1.bmp
# Skipping 1.bmp: No associated .xml file found.
# 10.bmp
# Skipping 10.bmp: No associated .xml file found.
# 100.bmp
# Skipping 100.bmp: No associated .xml file found.
# 1000.bmp
# Skipping 1000.bmp: No associated .xml file found.
# 1001.bmp
# 1001.xml
# 1002.bmp
# Skipping 1002.bmp: No associated .xml file found.
# 1003.bmp
# Skipping 1003.bmp: No associated .xml file found.
# 1004.bmp
# Skipping 1004.bmp: No associated .xml file found.
# 1005.bmp
# Skipping 1005.bmp: No associated .xml file found.
# 1006.bmp
# Skipping 1006.bmp: No associated .xml file found.
# 1007.bmp
# Skipping 1007.bmp: No associated .xml file found.
# 1008.bmp
# Skipping 1008.bmp: No associated .xml file found.
# 1009.bmp
# 1009.xml
# 101.bmp
# 101.xml
# 1010.bmp
# Skipping 1010.bmp: No associated .xml file found.
# 1011.bmp
# Skipping 1011.bmp: No associated .xml file found.
# 1012.bmp
# Skipping 1012.bmp: No associated .xml file found.
# 1013.bmp
# Skipping 1013.bmp: No associated .xml file found.
# 1014.bmp
# Skipping 1014.bmp: No associated .xml file found.
# 1015.bmp
# Skipping 1015.bmp: No associated .xml file found.
# 1016.bmp
# Skipping 1016.bmp: No associated .xml file found.
# 1017.bmp
# 1017.xml
# 1018.bmp
# Skipping 1018.bmp: No associated .xml file found.
# 1019.bmp
# Skipping 1019.bmp: No associated .xml file found.
# 102.bmp
# 102.xml
# 1020.bmp
# 1020.xml
# 1021.bmp
# Skipping 1021.bmp: No associated .xml file found.
# 1022.bmp
# Skipping 1022.bmp: No associated .xml file found.
# 1023.bmp
# Skipping 1023.bmp: No associated .xml file found.
# 1024.bmp
# Skipping 1024.bmp: No associated .xml file found.
# 1025.bmp
# Skipping 1025.bmp: No associated .xml file found.
# 1026.bmp
# 1026.xml
# 1027.bmp
# Skipping 1027.bmp: No associated .xml file found.
# 1028.bmp
# Skipping 1028.bmp: No associated .xml file found.
# 1029.bmp
# Skipping 1029.bmp: No associated .xml file found.
# 103.bmp
# Skipping 103.bmp: No associated .xml file found.
# 1030.bmp
# Skipping 1030.bmp: No associated .xml file found.
# 1031.bmp
# 1031.xml
# 1032.bmp
# 1032.xml
# 1033.bmp
# Skipping 1033.bmp: No associated .xml file found.
# 1034.bmp
# Skipping 1034.bmp: No associated .xml file found.
# 1035.bmp
# Skipping 1035.bmp: No associated .xml file found.
# 1036.bmp
# 1036.xml
# 1037.bmp
# Skipping 1037.bmp: No associated .xml file found.
# 1038.bmp
# Skipping 1038.bmp: No associated .xml file found.
# 1039.bmp
# Skipping 1039.bmp: No associated .xml file found.
# 104.bmp
# Skipping 104.bmp: No associated .xml file found.
# 1040.bmp
# Skipping 1040.bmp: No associated .xml file found.
# 1041.bmp
# 1041.xml
# 1042.bmp
# Skipping 1042.bmp: No associated .xml file found.
# 1043.bmp
# 1043.xml
# 1044.bmp
# 1044.xml
# 1045.bmp
# Skipping 1045.bmp: No associated .xml file found.
# 1046.bmp
# Skipping 1046.bmp: No associated .xml file found.
# 1047.bmp
# Skipping 1047.bmp: No associated .xml file found.
# 1048.bmp
# Skipping 1048.bmp: No associated .xml file found.
# 1049.bmp
# Skipping 1049.bmp: No associated .xml file found.
# 105.bmp
# Skipping 105.bmp: No associated .xml file found.
# 1050.bmp
# Skipping 1050.bmp: No associated .xml file found.
# 1051.bmp
# Skipping 1051.bmp: No associated .xml file found.
# 1052.bmp
# Skipping 1052.bmp: No associated .xml file found.
# 1053.bmp
# Skipping 1053.bmp: No associated .xml file found.
# 1054.bmp
# Skipping 1054.bmp: No associated .xml file found.
# 1055.bmp
# Skipping 1055.bmp: No associated .xml file found.
# 1056.bmp
# Skipping 1056.bmp: No associated .xml file found.
# 1057.bmp
# Skipping 1057.bmp: No associated .xml file found.
# 1058.bmp
# Skipping 1058.bmp: No associated .xml file found.
# 1059.bmp
# Skipping 1059.bmp: No associated .xml file found.
# 106.bmp
# Skipping 106.bmp: No associated .xml file found.
# 1060.bmp
# Skipping 1060.bmp: No associated .xml file found.
# 1061.bmp
# Skipping 1061.bmp: No associated .xml file found.
# 1062.bmp
# Skipping 1062.bmp: No associated .xml file found.
# 1063.bmp
# Skipping 1063.bmp: No associated .xml file found.
# 1064.bmp
# Skipping 1064.bmp: No associated .xml file found.
# 1065.bmp
# Skipping 1065.bmp: No associated .xml file found.
# 1066.bmp
# Skipping 1066.bmp: No associated .xml file found.
# 1067.bmp
# Skipping 1067.bmp: No associated .xml file found.
# 1068.bmp
# Skipping 1068.bmp: No associated .xml file found.
# 1069.bmp
# Skipping 1069.bmp: No associated .xml file found.
# 107.bmp
# Skipping 107.bmp: No associated .xml file found.
# 1070.bmp
# Skipping 1070.bmp: No associated .xml file found.
# 1071.bmp
# Skipping 1071.bmp: No associated .xml file found.
# 1072.bmp
# 1072.xml
# 1073.bmp
# Skipping 1073.bmp: No associated .xml file found.
# 1074.bmp
# 1074.xml
# 1075.bmp
# 1075.xml
# 1076.bmp
# 1076.xml
# 1077.bmp
# 1077.xml
# 1078.bmp
# Skipping 1078.bmp: No associated .xml file found.
# 1079.bmp
# Skipping 1079.bmp: No associated .xml file found.
# 108.bmp
# Skipping 108.bmp: No associated .xml file found.
# 1080.bmp
# Skipping 1080.bmp: No associated .xml file found.
# 1081.bmp
# Skipping 1081.bmp: No associated .xml file found.
# 1082.bmp
# Skipping 1082.bmp: No associated .xml file found.
# 1083.bmp
# 1083.xml
# 1084.bmp
# Skipping 1084.bmp: No associated .xml file found.
# 1085.bmp
# 1085.xml
# 1086.bmp
# 1086.xml
# 1087.bmp
# 1087.xml
# 1088.bmp
# Skipping 1088.bmp: No associated .xml file found.
# 1089.bmp
# Skipping 1089.bmp: No associated .xml file found.
# 109.bmp
# Skipping 109.bmp: No associated .xml file found.
# 1090.bmp
# Skipping 1090.bmp: No associated .xml file found.
# 1091.bmp
# Skipping 1091.bmp: No associated .xml file found.
# 1092.bmp
# Skipping 1092.bmp: No associated .xml file found.
# 1093.bmp
# Skipping 1093.bmp: No associated .xml file found.
# 1094.bmp
# Skipping 1094.bmp: No associated .xml file found.
# 1095.bmp
# 1095.xml
# 1096.bmp
# 1096.xml
# 1097.bmp
# Skipping 1097.bmp: No associated .xml file found.
# 1098.bmp
# Skipping 1098.bmp: No associated .xml file found.
# 1099.bmp
# Skipping 1099.bmp: No associated .xml file found.
# 11.bmp
# Skipping 11.bmp: No associated .xml file found.
# 110.bmp
# 110.xml
# 1100.bmp
# 1100.xml
# 1101.bmp
# Skipping 1101.bmp: No associated .xml file found.
# 1102.bmp
# Skipping 1102.bmp: No associated .xml file found.
# 1103.bmp
# Skipping 1103.bmp: No associated .xml file found.
# 1104.bmp
# Skipping 1104.bmp: No associated .xml file found.
# 1105.bmp
# Skipping 1105.bmp: No associated .xml file found.
# 1106.bmp
# Skipping 1106.bmp: No associated .xml file found.
# 1107.bmp
# Skipping 1107.bmp: No associated .xml file found.
# 1108.bmp
# Skipping 1108.bmp: No associated .xml file found.
# 1109.bmp
# Skipping 1109.bmp: No associated .xml file found.
# 111.bmp
# Skipping 111.bmp: No associated .xml file found.
# 1110.bmp
# Skipping 1110.bmp: No associated .xml file found.
# 1111.bmp
# Skipping 1111.bmp: No associated .xml file found.
# 1112.bmp
# Skipping 1112.bmp: No associated .xml file found.
# 1113.bmp
# Skipping 1113.bmp: No associated .xml file found.
# 1114.bmp
# Skipping 1114.bmp: No associated .xml file found.
# 1115.bmp
# Skipping 1115.bmp: No associated .xml file found.
# 1116.bmp
# Skipping 1116.bmp: No associated .xml file found.
# 1117.bmp
# Skipping 1117.bmp: No associated .xml file found.
# 1118.bmp
# Skipping 1118.bmp: No associated .xml file found.
# 1119.bmp
# Skipping 1119.bmp: No associated .xml file found.
# 112.bmp
# Skipping 112.bmp: No associated .xml file found.
# 1120.bmp
# Skipping 1120.bmp: No associated .xml file found.
# 1121.bmp
# Skipping 1121.bmp: No associated .xml file found.
# 1122.bmp
# Skipping 1122.bmp: No associated .xml file found.
# 1123.bmp
# Skipping 1123.bmp: No associated .xml file found.
# 1124.bmp
# Skipping 1124.bmp: No associated .xml file found.
# 1125.bmp
# Skipping 1125.bmp: No associated .xml file found.
# 1126.bmp
# Skipping 1126.bmp: No associated .xml file found.
# 1127.bmp
# Skipping 1127.bmp: No associated .xml file found.
# 1128.bmp
# Skipping 1128.bmp: No associated .xml file found.
# 1129.bmp
# Skipping 1129.bmp: No associated .xml file found.
# 113.bmp
# Skipping 113.bmp: No associated .xml file found.
# 1130.bmp
# Skipping 1130.bmp: No associated .xml file found.
# 1131.bmp
# Skipping 1131.bmp: No associated .xml file found.
# 1132.bmp
# Skipping 1132.bmp: No associated .xml file found.
# 1133.bmp
# Skipping 1133.bmp: No associated .xml file found.
# 1134.bmp
# Skipping 1134.bmp: No associated .xml file found.
# 1135.bmp
# Skipping 1135.bmp: No associated .xml file found.
# 1136.bmp
# Skipping 1136.bmp: No associated .xml file found.
# 1137.bmp
# Skipping 1137.bmp: No associated .xml file found.
# 1138.bmp
# Skipping 1138.bmp: No associated .xml file found.
# 1139.bmp
# Skipping 1139.bmp: No associated .xml file found.
# 114.bmp
# Skipping 114.bmp: No associated .xml file found.
# 1140.bmp
# Skipping 1140.bmp: No associated .xml file found.
# 1141.bmp
# Skipping 1141.bmp: No associated .xml file found.
# 1142.bmp
# Skipping 1142.bmp: No associated .xml file found.
# 1143.bmp
# Skipping 1143.bmp: No associated .xml file found.
# 1144.bmp
# Skipping 1144.bmp: No associated .xml file found.
# 1145.bmp
# Skipping 1145.bmp: No associated .xml file found.
# 1146.bmp
# Skipping 1146.bmp: No associated .xml file found.
# 1147.bmp
# 1147.xml
# 1148.bmp
# Skipping 1148.bmp: No associated .xml file found.
# 1149.bmp
# Skipping 1149.bmp: No associated .xml file found.
# 115.bmp
# Skipping 115.bmp: No associated .xml file found.
# 1150.bmp
# Skipping 1150.bmp: No associated .xml file found.
# 1151.bmp
# Skipping 1151.bmp: No associated .xml file found.
# 1152.bmp
# Skipping 1152.bmp: No associated .xml file found.
# 1153.bmp
# 1153.xml
# 1154.bmp
# Skipping 1154.bmp: No associated .xml file found.
# 1155.bmp
# Skipping 1155.bmp: No associated .xml file found.
# 1156.bmp
# Skipping 1156.bmp: No associated .xml file found.
# 1157.bmp
# Skipping 1157.bmp: No associated .xml file found.
# 1158.bmp
# Skipping 1158.bmp: No associated .xml file found.
# 1159.bmp
# Skipping 1159.bmp: No associated .xml file found.
# 116.bmp
# Skipping 116.bmp: No associated .xml file found.
# 1160.bmp
# Skipping 1160.bmp: No associated .xml file found.
# 1161.bmp
# Skipping 1161.bmp: No associated .xml file found.
# 1162.bmp
# Skipping 1162.bmp: No associated .xml file found.
# 1163.bmp
# Skipping 1163.bmp: No associated .xml file found.
# 1164.bmp
# Skipping 1164.bmp: No associated .xml file found.
# 1165.bmp
# Skipping 1165.bmp: No associated .xml file found.
# 1166.bmp
# Skipping 1166.bmp: No associated .xml file found.
# 1167.bmp
# Skipping 1167.bmp: No associated .xml file found.
# 1168.bmp
# Skipping 1168.bmp: No associated .xml file found.
# 1169.bmp
# Skipping 1169.bmp: No associated .xml file found.
# 117.bmp
# 117.xml
# 1170.bmp
# Skipping 1170.bmp: No associated .xml file found.
# 1171.bmp
# Skipping 1171.bmp: No associated .xml file found.
# 1172.bmp
# Skipping 1172.bmp: No associated .xml file found.
# 1173.bmp
# Skipping 1173.bmp: No associated .xml file found.
# 1174.bmp
# Skipping 1174.bmp: No associated .xml file found.
# 1175.bmp
# Skipping 1175.bmp: No associated .xml file found.
# 1176.bmp
# Skipping 1176.bmp: No associated .xml file found.
# 1177.bmp
# Skipping 1177.bmp: No associated .xml file found.
# 1178.bmp
# Skipping 1178.bmp: No associated .xml file found.
# 1179.bmp
# Skipping 1179.bmp: No associated .xml file found.
# 118.bmp
# Skipping 118.bmp: No associated .xml file found.
# 1180.bmp
# Skipping 1180.bmp: No associated .xml file found.
# 1181.bmp
# Skipping 1181.bmp: No associated .xml file found.
# 1182.bmp
# Skipping 1182.bmp: No associated .xml file found.
# 1183.bmp
# Skipping 1183.bmp: No associated .xml file found.
# 1184.bmp
# Skipping 1184.bmp: No associated .xml file found.
# 1185.bmp
# Skipping 1185.bmp: No associated .xml file found.
# 1186.bmp
# Skipping 1186.bmp: No associated .xml file found.
# 1187.bmp
# Skipping 1187.bmp: No associated .xml file found.
# 1188.bmp
# Skipping 1188.bmp: No associated .xml file found.
# 1189.bmp
# Skipping 1189.bmp: No associated .xml file found.
# 119.bmp
# Skipping 119.bmp: No associated .xml file found.
# 1190.bmp
# Skipping 1190.bmp: No associated .xml file found.
# 1191.bmp
# Skipping 1191.bmp: No associated .xml file found.
# 1192.bmp
# Skipping 1192.bmp: No associated .xml file found.
# 1193.bmp
# Skipping 1193.bmp: No associated .xml file found.
# 1194.bmp
# Skipping 1194.bmp: No associated .xml file found.
# 1195.bmp
# Skipping 1195.bmp: No associated .xml file found.
# 1196.bmp
# Skipping 1196.bmp: No associated .xml file found.
# 1197.bmp
# Skipping 1197.bmp: No associated .xml file found.
# 1198.bmp
# Skipping 1198.bmp: No associated .xml file found.
# 1199.bmp
# Skipping 1199.bmp: No associated .xml file found.
# 12.bmp
# Skipping 12.bmp: No associated .xml file found.
# 120.bmp
# Skipping 120.bmp: No associated .xml file found.
# 1200.bmp
# Skipping 1200.bmp: No associated .xml file found.
# 1201.bmp
# Skipping 1201.bmp: No associated .xml file found.
# 1202.bmp
# Skipping 1202.bmp: No associated .xml file found.
# 1203.bmp
# Skipping 1203.bmp: No associated .xml file found.
# 1204.bmp
# Skipping 1204.bmp: No associated .xml file found.
# 1205.bmp
# Skipping 1205.bmp: No associated .xml file found.
# 1206.bmp
# Skipping 1206.bmp: No associated .xml file found.
# 1207.bmp
# Skipping 1207.bmp: No associated .xml file found.
# 1208.bmp
# Skipping 1208.bmp: No associated .xml file found.
# 1209.bmp
# Skipping 1209.bmp: No associated .xml file found.
# 121.bmp
# Skipping 121.bmp: No associated .xml file found.
# 1210.bmp
# Skipping 1210.bmp: No associated .xml file found.
# 1211.bmp
# Skipping 1211.bmp: No associated .xml file found.
# 1212.bmp
# Skipping 1212.bmp: No associated .xml file found.
# 1213.bmp
# Skipping 1213.bmp: No associated .xml file found.
# 1214.bmp
# Skipping 1214.bmp: No associated .xml file found.
# 1215.bmp
# Skipping 1215.bmp: No associated .xml file found.
# 1216.bmp
# Skipping 1216.bmp: No associated .xml file found.
# 1217.bmp
# Skipping 1217.bmp: No associated .xml file found.
# 1218.bmp
# Skipping 1218.bmp: No associated .xml file found.
# 1219.bmp
# Skipping 1219.bmp: No associated .xml file found.
# 122.bmp
# Skipping 122.bmp: No associated .xml file found.
# 1220.bmp
# Skipping 1220.bmp: No associated .xml file found.
# 1221.bmp
# Skipping 1221.bmp: No associated .xml file found.
# 1222.bmp
# Skipping 1222.bmp: No associated .xml file found.
# 1223.bmp
# Skipping 1223.bmp: No associated .xml file found.
# 1224.bmp
# Skipping 1224.bmp: No associated .xml file found.
# 1225.bmp
# Skipping 1225.bmp: No associated .xml file found.
# 1226.bmp
# Skipping 1226.bmp: No associated .xml file found.
# 1227.bmp
# Skipping 1227.bmp: No associated .xml file found.
# 1228.bmp
# Skipping 1228.bmp: No associated .xml file found.
# 1229.bmp
# Skipping 1229.bmp: No associated .xml file found.
# 123.bmp
# Skipping 123.bmp: No associated .xml file found.
# 1230.bmp
# Skipping 1230.bmp: No associated .xml file found.
# 1231.bmp
# Skipping 1231.bmp: No associated .xml file found.
# 1232.bmp
# Skipping 1232.bmp: No associated .xml file found.
# 1233.bmp
# Skipping 1233.bmp: No associated .xml file found.
# 1234.bmp
# Skipping 1234.bmp: No associated .xml file found.
# 1235.bmp
# Skipping 1235.bmp: No associated .xml file found.
# 1236.bmp
# Skipping 1236.bmp: No associated .xml file found.
# 1237.bmp
# Skipping 1237.bmp: No associated .xml file found.
# 1238.bmp
# Skipping 1238.bmp: No associated .xml file found.
# 1239.bmp
# Skipping 1239.bmp: No associated .xml file found.
# 124.bmp
# Skipping 124.bmp: No associated .xml file found.
# 1240.bmp
# Skipping 1240.bmp: No associated .xml file found.
# 1241.bmp
# Skipping 1241.bmp: No associated .xml file found.
# 1242.bmp
# Skipping 1242.bmp: No associated .xml file found.
# 1243.bmp
# Skipping 1243.bmp: No associated .xml file found.
# 1244.bmp
# Skipping 1244.bmp: No associated .xml file found.
# 1245.bmp
# Skipping 1245.bmp: No associated .xml file found.
# 1246.bmp
# 1246.xml
# 1247.bmp
# 1247.xml
# 1248.bmp
# Skipping 1248.bmp: No associated .xml file found.
# 1249.bmp
# Skipping 1249.bmp: No associated .xml file found.
# 125.bmp
# Skipping 125.bmp: No associated .xml file found.
# 1250.bmp
# Skipping 1250.bmp: No associated .xml file found.
# 1251.bmp
# Skipping 1251.bmp: No associated .xml file found.
# 1252.bmp
# Skipping 1252.bmp: No associated .xml file found.
# 1253.bmp
# Skipping 1253.bmp: No associated .xml file found.
# 1254.bmp
# Skipping 1254.bmp: No associated .xml file found.
# 1255.bmp
# Skipping 1255.bmp: No associated .xml file found.
# 1256.bmp
# Skipping 1256.bmp: No associated .xml file found.
# 1257.bmp
# Skipping 1257.bmp: No associated .xml file found.
# 1258.bmp
# Skipping 1258.bmp: No associated .xml file found.
# 1259.bmp
# Skipping 1259.bmp: No associated .xml file found.
# 126.bmp
# Skipping 126.bmp: No associated .xml file found.
# 1260.bmp
# 1260.xml
# 1261.bmp
# 1261.xml
# 1262.bmp
# Skipping 1262.bmp: No associated .xml file found.
# 1263.bmp
# Skipping 1263.bmp: No associated .xml file found.
# 1264.bmp
# Skipping 1264.bmp: No associated .xml file found.
# 1265.bmp
# Skipping 1265.bmp: No associated .xml file found.
# 1266.bmp
# Skipping 1266.bmp: No associated .xml file found.
# 1267.bmp
# Skipping 1267.bmp: No associated .xml file found.
# 1268.bmp
# Skipping 1268.bmp: No associated .xml file found.
# 1269.bmp
# Skipping 1269.bmp: No associated .xml file found.
# 127.bmp
# Skipping 127.bmp: No associated .xml file found.
# 1270.bmp
# Skipping 1270.bmp: No associated .xml file found.
# 1271.bmp
# Skipping 1271.bmp: No associated .xml file found.
# 1272.bmp
# Skipping 1272.bmp: No associated .xml file found.
# 1273.bmp
# Skipping 1273.bmp: No associated .xml file found.
# 1274.bmp
# Skipping 1274.bmp: No associated .xml file found.
# 1275.bmp
# Skipping 1275.bmp: No associated .xml file found.
# 1276.bmp
# Skipping 1276.bmp: No associated .xml file found.
# 1277.bmp
# Skipping 1277.bmp: No associated .xml file found.
# 1278.bmp
# Skipping 1278.bmp: No associated .xml file found.
# 1279.bmp
# Skipping 1279.bmp: No associated .xml file found.
# 128.bmp
# Skipping 128.bmp: No associated .xml file found.
# 1280.bmp
# Skipping 1280.bmp: No associated .xml file found.
# 1281.bmp
# Skipping 1281.bmp: No associated .xml file found.
# 1282.bmp
# Skipping 1282.bmp: No associated .xml file found.
# 1283.bmp
# Skipping 1283.bmp: No associated .xml file found.
# 1284.bmp
# Skipping 1284.bmp: No associated .xml file found.
# 1285.bmp
# Skipping 1285.bmp: No associated .xml file found.
# 1286.bmp
# 1286.xml
# 1287.bmp
# Skipping 1287.bmp: No associated .xml file found.
# 1288.bmp
# Skipping 1288.bmp: No associated .xml file found.
# 1289.bmp
# Skipping 1289.bmp: No associated .xml file found.
# 129.bmp
# Skipping 129.bmp: No associated .xml file found.
# 1290.bmp
# Skipping 1290.bmp: No associated .xml file found.
# 1291.bmp
# Skipping 1291.bmp: No associated .xml file found.
# 1292.bmp
# Skipping 1292.bmp: No associated .xml file found.
# 1293.bmp
# Skipping 1293.bmp: No associated .xml file found.
# 1294.bmp
# Skipping 1294.bmp: No associated .xml file found.
# 1295.bmp
# 1295.xml
# 1296.bmp
# 1296.xml
# 1297.bmp
# 1297.xml
# 1298.bmp
# 1298.xml
# 1299.bmp
# 1299.xml
# 13.bmp
# Skipping 13.bmp: No associated .xml file found.
# 130.bmp
# Skipping 130.bmp: No associated .xml file found.
# 1300.bmp
# Skipping 1300.bmp: No associated .xml file found.
# 1301.bmp
# Skipping 1301.bmp: No associated .xml file found.
# 1302.bmp
# Skipping 1302.bmp: No associated .xml file found.
# 1303.bmp
# Skipping 1303.bmp: No associated .xml file found.
# 1304.bmp
# Skipping 1304.bmp: No associated .xml file found.
# 1305.bmp
# Skipping 1305.bmp: No associated .xml file found.
# 1306.bmp
# Skipping 1306.bmp: No associated .xml file found.
# 1307.bmp
# Skipping 1307.bmp: No associated .xml file found.
# 1308.bmp
# Skipping 1308.bmp: No associated .xml file found.
# 1309.bmp
# Skipping 1309.bmp: No associated .xml file found.
# 131.bmp
# Skipping 131.bmp: No associated .xml file found.
# 1310.bmp
# Skipping 1310.bmp: No associated .xml file found.
# 1311.bmp
# Skipping 1311.bmp: No associated .xml file found.
# 1312.bmp
# Skipping 1312.bmp: No associated .xml file found.
# 1313.bmp
# Skipping 1313.bmp: No associated .xml file found.
# 1314.bmp
# Skipping 1314.bmp: No associated .xml file found.
# 1315.bmp
# Skipping 1315.bmp: No associated .xml file found.
# 1316.bmp
# Skipping 1316.bmp: No associated .xml file found.
# 1317.bmp
# Skipping 1317.bmp: No associated .xml file found.
# 1318.bmp
# Skipping 1318.bmp: No associated .xml file found.
# 1319.bmp
# Skipping 1319.bmp: No associated .xml file found.
# 132.bmp
# Skipping 132.bmp: No associated .xml file found.
# 1320.bmp
# Skipping 1320.bmp: No associated .xml file found.
# 1321.bmp
# Skipping 1321.bmp: No associated .xml file found.
# 1322.bmp
# Skipping 1322.bmp: No associated .xml file found.
# 1323.bmp
# Skipping 1323.bmp: No associated .xml file found.
# 1324.bmp
# Skipping 1324.bmp: No associated .xml file found.
# 1325.bmp
# Skipping 1325.bmp: No associated .xml file found.
# 1326.bmp
# Skipping 1326.bmp: No associated .xml file found.
# 1327.bmp
# Skipping 1327.bmp: No associated .xml file found.
# 1328.bmp
# Skipping 1328.bmp: No associated .xml file found.
# 1329.bmp
# 1329.xml
# 133.bmp
# Skipping 133.bmp: No associated .xml file found.
# 1330.bmp
# 1330.xml
# 1331.bmp
# 1331.xml
# 1332.bmp
# 1332.xml
# 1333.bmp
# Skipping 1333.bmp: No associated .xml file found.
# 1334.bmp
# Skipping 1334.bmp: No associated .xml file found.
# 1335.bmp
# Skipping 1335.bmp: No associated .xml file found.
# 1336.bmp
# Skipping 1336.bmp: No associated .xml file found.
# 1337.bmp
# Skipping 1337.bmp: No associated .xml file found.
# 1338.bmp
# Skipping 1338.bmp: No associated .xml file found.
# 1339.bmp
# Skipping 1339.bmp: No associated .xml file found.
# 134.bmp
# 134.xml
# 1340.bmp
# Skipping 1340.bmp: No associated .xml file found.
# 1341.bmp
# Skipping 1341.bmp: No associated .xml file found.
# 1342.bmp
# Skipping 1342.bmp: No associated .xml file found.
# 1343.bmp
# 1343.xml
# 1344.bmp
# Skipping 1344.bmp: No associated .xml file found.
# 1345.bmp
# Skipping 1345.bmp: No associated .xml file found.
# 1346.bmp
# Skipping 1346.bmp: No associated .xml file found.
# 1347.bmp
# Skipping 1347.bmp: No associated .xml file found.
# 1348.bmp
# Skipping 1348.bmp: No associated .xml file found.
# 1349.bmp
# Skipping 1349.bmp: No associated .xml file found.
# 135.bmp
# Skipping 135.bmp: No associated .xml file found.
# 1350.bmp
# Skipping 1350.bmp: No associated .xml file found.
# 1351.bmp
# Skipping 1351.bmp: No associated .xml file found.
# 1352.bmp
# Skipping 1352.bmp: No associated .xml file found.
# 1353.bmp
# Skipping 1353.bmp: No associated .xml file found.
# 1354.bmp
# Skipping 1354.bmp: No associated .xml file found.
# 1355.bmp
# Skipping 1355.bmp: No associated .xml file found.
# 1356.bmp
# Skipping 1356.bmp: No associated .xml file found.
# 1357.bmp
# Skipping 1357.bmp: No associated .xml file found.
# 1358.bmp
# Skipping 1358.bmp: No associated .xml file found.
# 1359.bmp
# Skipping 1359.bmp: No associated .xml file found.
# 136.bmp
# Skipping 136.bmp: No associated .xml file found.
# 1360.bmp
# Skipping 1360.bmp: No associated .xml file found.
# 1361.bmp
# Skipping 1361.bmp: No associated .xml file found.
# 1362.bmp
# Skipping 1362.bmp: No associated .xml file found.
# 1363.bmp
# Skipping 1363.bmp: No associated .xml file found.
# 1364.bmp
# Skipping 1364.bmp: No associated .xml file found.
# 1365.bmp
# Skipping 1365.bmp: No associated .xml file found.
# 1366.bmp
# Skipping 1366.bmp: No associated .xml file found.
# 1367.bmp
# 1367.xml
# 1368.bmp
# 1368.xml
# 1369.bmp
# Skipping 1369.bmp: No associated .xml file found.
# 137.bmp
# Skipping 137.bmp: No associated .xml file found.
# 1370.bmp
# Skipping 1370.bmp: No associated .xml file found.
# 1371.bmp
# Skipping 1371.bmp: No associated .xml file found.
# 1372.bmp
# Skipping 1372.bmp: No associated .xml file found.
# 1373.bmp
# Skipping 1373.bmp: No associated .xml file found.
# 1374.bmp
# Skipping 1374.bmp: No associated .xml file found.
# 1375.bmp
# Skipping 1375.bmp: No associated .xml file found.
# 1376.bmp
# Skipping 1376.bmp: No associated .xml file found.
# 1377.bmp
# Skipping 1377.bmp: No associated .xml file found.
# 1378.bmp
# Skipping 1378.bmp: No associated .xml file found.
# 1379.bmp
# Skipping 1379.bmp: No associated .xml file found.
# 138.bmp
# Skipping 138.bmp: No associated .xml file found.
# 1380.bmp
# Skipping 1380.bmp: No associated .xml file found.
# 1381.bmp
# Skipping 1381.bmp: No associated .xml file found.
# 1382.bmp
# Skipping 1382.bmp: No associated .xml file found.
# 1383.bmp
# Skipping 1383.bmp: No associated .xml file found.
# 1384.bmp
# Skipping 1384.bmp: No associated .xml file found.
# 1385.bmp
# Skipping 1385.bmp: No associated .xml file found.
# 1386.bmp
# Skipping 1386.bmp: No associated .xml file found.
# 1387.bmp
# Skipping 1387.bmp: No associated .xml file found.
# 1388.bmp
# Skipping 1388.bmp: No associated .xml file found.
# 1389.bmp
# Skipping 1389.bmp: No associated .xml file found.
# 139.bmp
# 139.xml
# 1390.bmp
# Skipping 1390.bmp: No associated .xml file found.
# 1391.bmp
# Skipping 1391.bmp: No associated .xml file found.
# 1392.bmp
# Skipping 1392.bmp: No associated .xml file found.
# 1393.bmp
# Skipping 1393.bmp: No associated .xml file found.
# 1394.bmp
# Skipping 1394.bmp: No associated .xml file found.
# 1395.bmp
# Skipping 1395.bmp: No associated .xml file found.
# 1396.bmp
# Skipping 1396.bmp: No associated .xml file found.
# 1397.bmp
# Skipping 1397.bmp: No associated .xml file found.
# 1398.bmp
# Skipping 1398.bmp: No associated .xml file found.
# 1399.bmp
# Skipping 1399.bmp: No associated .xml file found.
# 14.bmp
# Skipping 14.bmp: No associated .xml file found.
# 140.bmp
# Skipping 140.bmp: No associated .xml file found.
# 1400.bmp
# Skipping 1400.bmp: No associated .xml file found.
# 1401.bmp
# Skipping 1401.bmp: No associated .xml file found.
# 1402.bmp
# Skipping 1402.bmp: No associated .xml file found.
# 1403.bmp
# Skipping 1403.bmp: No associated .xml file found.
# 1404.bmp
# Skipping 1404.bmp: No associated .xml file found.
# 1405.bmp
# Skipping 1405.bmp: No associated .xml file found.
# 1406.bmp
# Skipping 1406.bmp: No associated .xml file found.
# 1407.bmp
# Skipping 1407.bmp: No associated .xml file found.
# 1408.bmp
# Skipping 1408.bmp: No associated .xml file found.
# 1409.bmp
# Skipping 1409.bmp: No associated .xml file found.
# 141.bmp
# Skipping 141.bmp: No associated .xml file found.
# 1410.bmp
# Skipping 1410.bmp: No associated .xml file found.
# 1411.bmp
# Skipping 1411.bmp: No associated .xml file found.
# 1412.bmp
# Skipping 1412.bmp: No associated .xml file found.
# 1413.bmp
# Skipping 1413.bmp: No associated .xml file found.
# 1414.bmp
# Skipping 1414.bmp: No associated .xml file found.
# 1415.bmp
# Skipping 1415.bmp: No associated .xml file found.
# 1416.bmp
# Skipping 1416.bmp: No associated .xml file found.
# 1417.bmp
# Skipping 1417.bmp: No associated .xml file found.
# 1418.bmp
# Skipping 1418.bmp: No associated .xml file found.
# 1419.bmp
# Skipping 1419.bmp: No associated .xml file found.
# 142.bmp
# Skipping 142.bmp: No associated .xml file found.
# 1420.bmp
# Skipping 1420.bmp: No associated .xml file found.
# 1421.bmp
# Skipping 1421.bmp: No associated .xml file found.
# 1422.bmp
# Skipping 1422.bmp: No associated .xml file found.
# 1423.bmp
# Skipping 1423.bmp: No associated .xml file found.
# 1424.bmp
# Skipping 1424.bmp: No associated .xml file found.
# 1425.bmp
# Skipping 1425.bmp: No associated .xml file found.
# 1426.bmp
# Skipping 1426.bmp: No associated .xml file found.
# 1427.bmp
# Skipping 1427.bmp: No associated .xml file found.
# 1428.bmp
# Skipping 1428.bmp: No associated .xml file found.
# 1429.bmp
# Skipping 1429.bmp: No associated .xml file found.
# 143.bmp
# Skipping 143.bmp: No associated .xml file found.
# 1430.bmp
# Skipping 1430.bmp: No associated .xml file found.
# 1431.bmp
# Skipping 1431.bmp: No associated .xml file found.
# 1432.bmp
# Skipping 1432.bmp: No associated .xml file found.
# 1433.bmp
# Skipping 1433.bmp: No associated .xml file found.
# 1434.bmp
# Skipping 1434.bmp: No associated .xml file found.
# 1435.bmp
# Skipping 1435.bmp: No associated .xml file found.
# 1436.bmp
# Skipping 1436.bmp: No associated .xml file found.
# 1437.bmp
# Skipping 1437.bmp: No associated .xml file found.
# 1438.bmp
# Skipping 1438.bmp: No associated .xml file found.
# 1439.bmp
# Skipping 1439.bmp: No associated .xml file found.
# 144.bmp
# Skipping 144.bmp: No associated .xml file found.
# 1440.bmp
# Skipping 1440.bmp: No associated .xml file found.
# 1441.bmp
# Skipping 1441.bmp: No associated .xml file found.
# 1442.bmp
# Skipping 1442.bmp: No associated .xml file found.
# 1443.bmp
# Skipping 1443.bmp: No associated .xml file found.
# 1444.bmp
# Skipping 1444.bmp: No associated .xml file found.
# 1445.bmp
# Skipping 1445.bmp: No associated .xml file found.
# 1446.bmp
# Skipping 1446.bmp: No associated .xml file found.
# 1447.bmp
# Skipping 1447.bmp: No associated .xml file found.
# 1448.bmp
# Skipping 1448.bmp: No associated .xml file found.
# 1449.bmp
# Skipping 1449.bmp: No associated .xml file found.
# 145.bmp
# Skipping 145.bmp: No associated .xml file found.
# 1450.bmp
# Skipping 1450.bmp: No associated .xml file found.
# 1451.bmp
# 1451.xml
# 1452.bmp
# Skipping 1452.bmp: No associated .xml file found.
# 1453.bmp
# Skipping 1453.bmp: No associated .xml file found.
# 1454.bmp
# Skipping 1454.bmp: No associated .xml file found.
# 1455.bmp
# Skipping 1455.bmp: No associated .xml file found.
# 1456.bmp
# Skipping 1456.bmp: No associated .xml file found.
# 1457.bmp
# Skipping 1457.bmp: No associated .xml file found.
# 1458.bmp
# Skipping 1458.bmp: No associated .xml file found.
# 1459.bmp
# Skipping 1459.bmp: No associated .xml file found.
# 146.bmp
# Skipping 146.bmp: No associated .xml file found.
# 1460.bmp
# Skipping 1460.bmp: No associated .xml file found.
# 1461.bmp
# Skipping 1461.bmp: No associated .xml file found.
# 1462.bmp
# Skipping 1462.bmp: No associated .xml file found.
# 1463.bmp
# Skipping 1463.bmp: No associated .xml file found.
# 1464.bmp
# Skipping 1464.bmp: No associated .xml file found.
# 1465.bmp
# Skipping 1465.bmp: No associated .xml file found.
# 1466.bmp
# Skipping 1466.bmp: No associated .xml file found.
# 1467.bmp
# Skipping 1467.bmp: No associated .xml file found.
# 1468.bmp
# Skipping 1468.bmp: No associated .xml file found.
# 1469.bmp
# Skipping 1469.bmp: No associated .xml file found.
# 147.bmp
# 147.xml
# 1470.bmp
# Skipping 1470.bmp: No associated .xml file found.
# 1471.bmp
# Skipping 1471.bmp: No associated .xml file found.
# 1472.bmp
# Skipping 1472.bmp: No associated .xml file found.
# 1473.bmp
# Skipping 1473.bmp: No associated .xml file found.
# 1474.bmp
# Skipping 1474.bmp: No associated .xml file found.
# 1475.bmp
# Skipping 1475.bmp: No associated .xml file found.
# 1476.bmp
# Skipping 1476.bmp: No associated .xml file found.
# 1477.bmp
# Skipping 1477.bmp: No associated .xml file found.
# 1478.bmp
# Skipping 1478.bmp: No associated .xml file found.
# 1479.bmp
# Skipping 1479.bmp: No associated .xml file found.
# 148.bmp
# Skipping 148.bmp: No associated .xml file found.
# 1480.bmp
# Skipping 1480.bmp: No associated .xml file found.
# 1481.bmp
# Skipping 1481.bmp: No associated .xml file found.
# 1482.bmp
# Skipping 1482.bmp: No associated .xml file found.
# 1483.bmp
# Skipping 1483.bmp: No associated .xml file found.
# 1484.bmp
# Skipping 1484.bmp: No associated .xml file found.
# 1485.bmp
# Skipping 1485.bmp: No associated .xml file found.
# 1486.bmp
# Skipping 1486.bmp: No associated .xml file found.
# 1487.bmp
# Skipping 1487.bmp: No associated .xml file found.
# 1488.bmp
# Skipping 1488.bmp: No associated .xml file found.
# 1489.bmp
# Skipping 1489.bmp: No associated .xml file found.
# 149.bmp
# Skipping 149.bmp: No associated .xml file found.
# 1490.bmp
# Skipping 1490.bmp: No associated .xml file found.
# 1491.bmp
# Skipping 1491.bmp: No associated .xml file found.
# 1492.bmp
# Skipping 1492.bmp: No associated .xml file found.
# 1493.bmp
# Skipping 1493.bmp: No associated .xml file found.
# 1494.bmp
# Skipping 1494.bmp: No associated .xml file found.
# 1495.bmp
# Skipping 1495.bmp: No associated .xml file found.
# 1496.bmp
# Skipping 1496.bmp: No associated .xml file found.
# 1497.bmp
# Skipping 1497.bmp: No associated .xml file found.
# 1498.bmp
# Skipping 1498.bmp: No associated .xml file found.
# 1499.bmp
# Skipping 1499.bmp: No associated .xml file found.
# 15.bmp
# Skipping 15.bmp: No associated .xml file found.
# 150.bmp
# Skipping 150.bmp: No associated .xml file found.
# 1500.bmp
# Skipping 1500.bmp: No associated .xml file found.
# 1501.bmp
# Skipping 1501.bmp: No associated .xml file found.
# 1502.bmp
# Skipping 1502.bmp: No associated .xml file found.
# 1503.bmp
# Skipping 1503.bmp: No associated .xml file found.
# 1504.bmp
# 1504.xml
# 1505.bmp
# Skipping 1505.bmp: No associated .xml file found.
# 1506.bmp
# Skipping 1506.bmp: No associated .xml file found.
# 1507.bmp
# Skipping 1507.bmp: No associated .xml file found.
# 1508.bmp
# Skipping 1508.bmp: No associated .xml file found.
# 1509.bmp
# Skipping 1509.bmp: No associated .xml file found.
# 151.bmp
# Skipping 151.bmp: No associated .xml file found.
# 1510.bmp
# Skipping 1510.bmp: No associated .xml file found.
# 1511.bmp
# Skipping 1511.bmp: No associated .xml file found.
# 1512.bmp
# Skipping 1512.bmp: No associated .xml file found.
# 1513.bmp
# Skipping 1513.bmp: No associated .xml file found.
# 1514.bmp
# Skipping 1514.bmp: No associated .xml file found.
# 1515.bmp
# Skipping 1515.bmp: No associated .xml file found.
# 1516.bmp
# Skipping 1516.bmp: No associated .xml file found.
# 1517.bmp
# Skipping 1517.bmp: No associated .xml file found.
# 1518.bmp
# Skipping 1518.bmp: No associated .xml file found.
# 1519.bmp
# Skipping 1519.bmp: No associated .xml file found.
# 152.bmp
# 152.xml
# 1520.bmp
# Skipping 1520.bmp: No associated .xml file found.
# 1521.bmp
# Skipping 1521.bmp: No associated .xml file found.
# 1522.bmp
# Skipping 1522.bmp: No associated .xml file found.
# 1523.bmp
# Skipping 1523.bmp: No associated .xml file found.
# 1524.bmp
# Skipping 1524.bmp: No associated .xml file found.
# 1525.bmp
# Skipping 1525.bmp: No associated .xml file found.
# 1526.bmp
# Skipping 1526.bmp: No associated .xml file found.
# 1527.bmp
# Skipping 1527.bmp: No associated .xml file found.
# 1528.bmp
# Skipping 1528.bmp: No associated .xml file found.
# 1529.bmp
# Skipping 1529.bmp: No associated .xml file found.
# 153.bmp
# Skipping 153.bmp: No associated .xml file found.
# 1530.bmp
# Skipping 1530.bmp: No associated .xml file found.
# 1531.bmp
# Skipping 1531.bmp: No associated .xml file found.
# 1532.bmp
# Skipping 1532.bmp: No associated .xml file found.
# 1533.bmp
# Skipping 1533.bmp: No associated .xml file found.
# 1534.bmp
# Skipping 1534.bmp: No associated .xml file found.
# 1535.bmp
# Skipping 1535.bmp: No associated .xml file found.
# 1536.bmp
# Skipping 1536.bmp: No associated .xml file found.
# 1537.bmp
# Skipping 1537.bmp: No associated .xml file found.
# 1538.bmp
# Skipping 1538.bmp: No associated .xml file found.
# 1539.bmp
# Skipping 1539.bmp: No associated .xml file found.
# 154.bmp
# Skipping 154.bmp: No associated .xml file found.
# 1540.bmp
# Skipping 1540.bmp: No associated .xml file found.
# 1541.bmp
# Skipping 1541.bmp: No associated .xml file found.
# 1542.bmp
# Skipping 1542.bmp: No associated .xml file found.
# 1543.bmp
# Skipping 1543.bmp: No associated .xml file found.
# 1544.bmp
# Skipping 1544.bmp: No associated .xml file found.
# 1545.bmp
# Skipping 1545.bmp: No associated .xml file found.
# 1546.bmp
# Skipping 1546.bmp: No associated .xml file found.
# 1547.bmp
# Skipping 1547.bmp: No associated .xml file found.
# 1548.bmp
# Skipping 1548.bmp: No associated .xml file found.
# 1549.bmp
# Skipping 1549.bmp: No associated .xml file found.
# 155.bmp
# Skipping 155.bmp: No associated .xml file found.
# 1550.bmp
# Skipping 1550.bmp: No associated .xml file found.
# 1551.bmp
# Skipping 1551.bmp: No associated .xml file found.
# 1552.bmp
# Skipping 1552.bmp: No associated .xml file found.
# 1553.bmp
# Skipping 1553.bmp: No associated .xml file found.
# 1554.bmp
# Skipping 1554.bmp: No associated .xml file found.
# 1555.bmp
# Skipping 1555.bmp: No associated .xml file found.
# 1556.bmp
# Skipping 1556.bmp: No associated .xml file found.
# 1557.bmp
# Skipping 1557.bmp: No associated .xml file found.
# 1558.bmp
# Skipping 1558.bmp: No associated .xml file found.
# 1559.bmp
# Skipping 1559.bmp: No associated .xml file found.
# 156.bmp
# Skipping 156.bmp: No associated .xml file found.
# 1560.bmp
# Skipping 1560.bmp: No associated .xml file found.
# 1561.bmp
# Skipping 1561.bmp: No associated .xml file found.
# 1562.bmp
# Skipping 1562.bmp: No associated .xml file found.
# 1563.bmp
# Skipping 1563.bmp: No associated .xml file found.
# 1564.bmp
# Skipping 1564.bmp: No associated .xml file found.
# 1565.bmp
# Skipping 1565.bmp: No associated .xml file found.
# 1566.bmp
# Skipping 1566.bmp: No associated .xml file found.
# 1567.bmp
# Skipping 1567.bmp: No associated .xml file found.
# 1568.bmp
# Skipping 1568.bmp: No associated .xml file found.
# 1569.bmp
# Skipping 1569.bmp: No associated .xml file found.
# 157.bmp
# Skipping 157.bmp: No associated .xml file found.
# 1570.bmp
# Skipping 1570.bmp: No associated .xml file found.
# 1571.bmp
# Skipping 1571.bmp: No associated .xml file found.
# 1572.bmp
# Skipping 1572.bmp: No associated .xml file found.
# 1573.bmp
# Skipping 1573.bmp: No associated .xml file found.
# 1574.bmp
# Skipping 1574.bmp: No associated .xml file found.
# 1575.bmp
# Skipping 1575.bmp: No associated .xml file found.
# 1576.bmp
# Skipping 1576.bmp: No associated .xml file found.
# 1577.bmp
# Skipping 1577.bmp: No associated .xml file found.
# 1578.bmp
# Skipping 1578.bmp: No associated .xml file found.
# 1579.bmp
# 1579.xml
# 158.bmp
# Skipping 158.bmp: No associated .xml file found.
# 1580.bmp
# Skipping 1580.bmp: No associated .xml file found.
# 1581.bmp
# Skipping 1581.bmp: No associated .xml file found.
# 1582.bmp
# Skipping 1582.bmp: No associated .xml file found.
# 1583.bmp
# Skipping 1583.bmp: No associated .xml file found.
# 1584.bmp
# Skipping 1584.bmp: No associated .xml file found.
# 1585.bmp
# Skipping 1585.bmp: No associated .xml file found.
# 1586.bmp
# Skipping 1586.bmp: No associated .xml file found.
# 1587.bmp
# Skipping 1587.bmp: No associated .xml file found.
# 1588.bmp
# Skipping 1588.bmp: No associated .xml file found.
# 1589.bmp
# Skipping 1589.bmp: No associated .xml file found.
# 159.bmp
# Skipping 159.bmp: No associated .xml file found.
# 1590.bmp
# Skipping 1590.bmp: No associated .xml file found.
# 1591.bmp
# Skipping 1591.bmp: No associated .xml file found.
# 1592.bmp
# Skipping 1592.bmp: No associated .xml file found.
# 1593.bmp
# Skipping 1593.bmp: No associated .xml file found.
# 1594.bmp
# Skipping 1594.bmp: No associated .xml file found.
# 1595.bmp
# Skipping 1595.bmp: No associated .xml file found.
# 1596.bmp
# Skipping 1596.bmp: No associated .xml file found.
# 1597.bmp
# Skipping 1597.bmp: No associated .xml file found.
# 1598.bmp
# Skipping 1598.bmp: No associated .xml file found.
# 1599.bmp
# Skipping 1599.bmp: No associated .xml file found.
# 16.bmp
# Skipping 16.bmp: No associated .xml file found.
# 160.bmp
# Skipping 160.bmp: No associated .xml file found.
# 1600.bmp
# Skipping 1600.bmp: No associated .xml file found.
# 1601.bmp
# Skipping 1601.bmp: No associated .xml file found.
# 1602.bmp
# Skipping 1602.bmp: No associated .xml file found.
# 1603.bmp
# Skipping 1603.bmp: No associated .xml file found.
# 1604.bmp
# Skipping 1604.bmp: No associated .xml file found.
# 1605.bmp
# Skipping 1605.bmp: No associated .xml file found.
# 1606.bmp
# Skipping 1606.bmp: No associated .xml file found.
# 1607.bmp
# Skipping 1607.bmp: No associated .xml file found.
# 1608.bmp
# Skipping 1608.bmp: No associated .xml file found.
# 1609.bmp
# Skipping 1609.bmp: No associated .xml file found.
# 161.bmp
# Skipping 161.bmp: No associated .xml file found.
# 1610.bmp
# Skipping 1610.bmp: No associated .xml file found.
# 1611.bmp
# Skipping 1611.bmp: No associated .xml file found.
# 1612.bmp
# Skipping 1612.bmp: No associated .xml file found.
# 1613.bmp
# Skipping 1613.bmp: No associated .xml file found.
# 1614.bmp
# Skipping 1614.bmp: No associated .xml file found.
# 1615.bmp
# Skipping 1615.bmp: No associated .xml file found.
# 1616.bmp
# Skipping 1616.bmp: No associated .xml file found.
# 1617.bmp
# Skipping 1617.bmp: No associated .xml file found.
# 1618.bmp
# Skipping 1618.bmp: No associated .xml file found.
# 1619.bmp
# Skipping 1619.bmp: No associated .xml file found.
# 162.bmp
# Skipping 162.bmp: No associated .xml file found.
# 1620.bmp
# Skipping 1620.bmp: No associated .xml file found.
# 1621.bmp
# Skipping 1621.bmp: No associated .xml file found.
# 1622.bmp
# Skipping 1622.bmp: No associated .xml file found.
# 1623.bmp
# Skipping 1623.bmp: No associated .xml file found.
# 1624.bmp
# Skipping 1624.bmp: No associated .xml file found.
# 1625.bmp
# Skipping 1625.bmp: No associated .xml file found.
# 1626.bmp
# Skipping 1626.bmp: No associated .xml file found.
# 1627.bmp
# Skipping 1627.bmp: No associated .xml file found.
# 1628.bmp
# Skipping 1628.bmp: No associated .xml file found.
# 1629.bmp
# Skipping 1629.bmp: No associated .xml file found.
# 163.bmp
# Skipping 163.bmp: No associated .xml file found.
# 1630.bmp
# Skipping 1630.bmp: No associated .xml file found.
# 1631.bmp
# Skipping 1631.bmp: No associated .xml file found.
# 1632.bmp
# Skipping 1632.bmp: No associated .xml file found.
# 1633.bmp
# Skipping 1633.bmp: No associated .xml file found.
# 1634.bmp
# Skipping 1634.bmp: No associated .xml file found.
# 1635.bmp
# Skipping 1635.bmp: No associated .xml file found.
# 1636.bmp
# Skipping 1636.bmp: No associated .xml file found.
# 1637.bmp
# 1637.xml
# 1638.bmp
# Skipping 1638.bmp: No associated .xml file found.
# 1639.bmp
# Skipping 1639.bmp: No associated .xml file found.
# 164.bmp
# 164.xml
# 1640.bmp
# Skipping 1640.bmp: No associated .xml file found.
# 1641.bmp
# Skipping 1641.bmp: No associated .xml file found.
# 1642.bmp
# Skipping 1642.bmp: No associated .xml file found.
# 1643.bmp
# Skipping 1643.bmp: No associated .xml file found.
# 1644.bmp
# Skipping 1644.bmp: No associated .xml file found.
# 1645.bmp
# Skipping 1645.bmp: No associated .xml file found.
# 1646.bmp
# Skipping 1646.bmp: No associated .xml file found.
# 1647.bmp
# Skipping 1647.bmp: No associated .xml file found.
# 1648.bmp
# Skipping 1648.bmp: No associated .xml file found.
# 1649.bmp
# Skipping 1649.bmp: No associated .xml file found.
# 165.bmp
# Skipping 165.bmp: No associated .xml file found.
# 1650.bmp
# Skipping 1650.bmp: No associated .xml file found.
# 1651.bmp
# Skipping 1651.bmp: No associated .xml file found.
# 1652.bmp
# Skipping 1652.bmp: No associated .xml file found.
# 1653.bmp
# Skipping 1653.bmp: No associated .xml file found.
# 1654.bmp
# Skipping 1654.bmp: No associated .xml file found.
# 1655.bmp
# Skipping 1655.bmp: No associated .xml file found.
# 1656.bmp
# 1656.xml
# 1657.bmp
# Skipping 1657.bmp: No associated .xml file found.
# 1658.bmp
# Skipping 1658.bmp: No associated .xml file found.
# 1659.bmp
# Skipping 1659.bmp: No associated .xml file found.
# 166.bmp
# 166.xml
# 1660.bmp
# Skipping 1660.bmp: No associated .xml file found.
# 1661.bmp
# Skipping 1661.bmp: No associated .xml file found.
# 1662.bmp
# Skipping 1662.bmp: No associated .xml file found.
# 1663.bmp
# Skipping 1663.bmp: No associated .xml file found.
# 1664.bmp
# Skipping 1664.bmp: No associated .xml file found.
# 1665.bmp
# Skipping 1665.bmp: No associated .xml file found.
# 1666.bmp
# Skipping 1666.bmp: No associated .xml file found.
# 1667.bmp
# Skipping 1667.bmp: No associated .xml file found.
# 1668.bmp
# Skipping 1668.bmp: No associated .xml file found.
# 1669.bmp
# Skipping 1669.bmp: No associated .xml file found.
# 167.bmp
# Skipping 167.bmp: No associated .xml file found.
# 1670.bmp
# Skipping 1670.bmp: No associated .xml file found.
# 1671.bmp
# Skipping 1671.bmp: No associated .xml file found.
# 1672.bmp
# Skipping 1672.bmp: No associated .xml file found.
# 1673.bmp
# Skipping 1673.bmp: No associated .xml file found.
# 1674.bmp
# Skipping 1674.bmp: No associated .xml file found.
# 1675.bmp
# Skipping 1675.bmp: No associated .xml file found.
# 1676.bmp
# Skipping 1676.bmp: No associated .xml file found.
# 1677.bmp
# Skipping 1677.bmp: No associated .xml file found.
# 1678.bmp
# 1678.xml
# 1679.bmp
# Skipping 1679.bmp: No associated .xml file found.
# 168.bmp
# 168.xml
# 1680.bmp
# Skipping 1680.bmp: No associated .xml file found.
# 1681.bmp
# Skipping 1681.bmp: No associated .xml file found.
# 1682.bmp
# Skipping 1682.bmp: No associated .xml file found.
# 1683.bmp
# Skipping 1683.bmp: No associated .xml file found.
# 1684.bmp
# Skipping 1684.bmp: No associated .xml file found.
# 1685.bmp
# Skipping 1685.bmp: No associated .xml file found.
# 1686.bmp
# Skipping 1686.bmp: No associated .xml file found.
# 1687.bmp
# Skipping 1687.bmp: No associated .xml file found.
# 1688.bmp
# Skipping 1688.bmp: No associated .xml file found.
# 1689.bmp
# Skipping 1689.bmp: No associated .xml file found.
# 169.bmp
# Skipping 169.bmp: No associated .xml file found.
# 1690.bmp
# Skipping 1690.bmp: No associated .xml file found.
# 1691.bmp
# Skipping 1691.bmp: No associated .xml file found.
# 1692.bmp
# Skipping 1692.bmp: No associated .xml file found.
# 1693.bmp
# Skipping 1693.bmp: No associated .xml file found.
# 1694.bmp
# Skipping 1694.bmp: No associated .xml file found.
# 1695.bmp
# Skipping 1695.bmp: No associated .xml file found.
# 1696.bmp
# Skipping 1696.bmp: No associated .xml file found.
# 1697.bmp
# Skipping 1697.bmp: No associated .xml file found.
# 1698.bmp
# Skipping 1698.bmp: No associated .xml file found.
# 1699.bmp
# Skipping 1699.bmp: No associated .xml file found.
# 17.bmp
# Skipping 17.bmp: No associated .xml file found.
# 170.bmp
# Skipping 170.bmp: No associated .xml file found.
# 1700.bmp
# Skipping 1700.bmp: No associated .xml file found.
# 1701.bmp
# Skipping 1701.bmp: No associated .xml file found.
# 1702.bmp
# Skipping 1702.bmp: No associated .xml file found.
# 1703.bmp
# Skipping 1703.bmp: No associated .xml file found.
# 1704.bmp
# Skipping 1704.bmp: No associated .xml file found.
# 1705.bmp
# Skipping 1705.bmp: No associated .xml file found.
# 1706.bmp
# Skipping 1706.bmp: No associated .xml file found.
# 1707.bmp
# Skipping 1707.bmp: No associated .xml file found.
# 1708.bmp
# Skipping 1708.bmp: No associated .xml file found.
# 1709.bmp
# Skipping 1709.bmp: No associated .xml file found.
# 171.bmp
# Skipping 171.bmp: No associated .xml file found.
# 1710.bmp
# Skipping 1710.bmp: No associated .xml file found.
# 1711.bmp
# Skipping 1711.bmp: No associated .xml file found.
# 1712.bmp
# Skipping 1712.bmp: No associated .xml file found.
# 1713.bmp
# Skipping 1713.bmp: No associated .xml file found.
# 1714.bmp
# Skipping 1714.bmp: No associated .xml file found.
# 1715.bmp
# Skipping 1715.bmp: No associated .xml file found.
# 1716.bmp
# Skipping 1716.bmp: No associated .xml file found.
# 1717.bmp
# Skipping 1717.bmp: No associated .xml file found.
# 1718.bmp
# Skipping 1718.bmp: No associated .xml file found.
# 1719.bmp
# Skipping 1719.bmp: No associated .xml file found.
# 172.bmp
# Skipping 172.bmp: No associated .xml file found.
# 1720.bmp
# Skipping 1720.bmp: No associated .xml file found.
# 1721.bmp
# Skipping 1721.bmp: No associated .xml file found.
# 1722.bmp
# Skipping 1722.bmp: No associated .xml file found.
# 1723.bmp
# Skipping 1723.bmp: No associated .xml file found.
# 1724.bmp
# Skipping 1724.bmp: No associated .xml file found.
# 1725.bmp
# Skipping 1725.bmp: No associated .xml file found.
# 1726.bmp
# Skipping 1726.bmp: No associated .xml file found.
# 1727.bmp
# Skipping 1727.bmp: No associated .xml file found.
# 1728.bmp
# Skipping 1728.bmp: No associated .xml file found.
# 1729.bmp
# Skipping 1729.bmp: No associated .xml file found.
# 173.bmp
# 173.xml
# 1730.bmp
# Skipping 1730.bmp: No associated .xml file found.
# 1731.bmp
# Skipping 1731.bmp: No associated .xml file found.
# 1732.bmp
# Skipping 1732.bmp: No associated .xml file found.
# 1733.bmp
# 1733.xml
# 1734.bmp
# Skipping 1734.bmp: No associated .xml file found.
# 1735.bmp
# Skipping 1735.bmp: No associated .xml file found.
# 1736.bmp
# Skipping 1736.bmp: No associated .xml file found.
# 1737.bmp
# Skipping 1737.bmp: No associated .xml file found.
# 1738.bmp
# Skipping 1738.bmp: No associated .xml file found.
# 1739.bmp
# Skipping 1739.bmp: No associated .xml file found.
# 174.bmp
# Skipping 174.bmp: No associated .xml file found.
# 1740.bmp
# Skipping 1740.bmp: No associated .xml file found.
# 1741.bmp
# Skipping 1741.bmp: No associated .xml file found.
# 1742.bmp
# Skipping 1742.bmp: No associated .xml file found.
# 1743.bmp
# Skipping 1743.bmp: No associated .xml file found.
# 1744.bmp
# Skipping 1744.bmp: No associated .xml file found.
# 1745.bmp
# Skipping 1745.bmp: No associated .xml file found.
# 1746.bmp
# 1746.xml
# 1747.bmp
# 1747.xml
# 1748.bmp
# Skipping 1748.bmp: No associated .xml file found.
# 1749.bmp
# 1749.xml
# 175.bmp
# Skipping 175.bmp: No associated .xml file found.
# 1750.bmp
# Skipping 1750.bmp: No associated .xml file found.
# 1751.bmp
# Skipping 1751.bmp: No associated .xml file found.
# 1752.bmp
# Skipping 1752.bmp: No associated .xml file found.
# 1753.bmp
# 1753.xml
# 1754.bmp
# 1754.xml
# 1755.bmp
# Skipping 1755.bmp: No associated .xml file found.
# 1756.bmp
# Skipping 1756.bmp: No associated .xml file found.
# 1757.bmp
# Skipping 1757.bmp: No associated .xml file found.
# 1758.bmp
# Skipping 1758.bmp: No associated .xml file found.
# 1759.bmp
# Skipping 1759.bmp: No associated .xml file found.
# 176.bmp
# Skipping 176.bmp: No associated .xml file found.
# 1760.bmp
# Skipping 1760.bmp: No associated .xml file found.
# 1761.bmp
# Skipping 1761.bmp: No associated .xml file found.
# 1762.bmp
# Skipping 1762.bmp: No associated .xml file found.
# 1763.bmp
# Skipping 1763.bmp: No associated .xml file found.
# 1764.bmp
# Skipping 1764.bmp: No associated .xml file found.
# 1765.bmp
# Skipping 1765.bmp: No associated .xml file found.
# 1766.bmp
# Skipping 1766.bmp: No associated .xml file found.
# 1767.bmp
# Skipping 1767.bmp: No associated .xml file found.
# 1768.bmp
# Skipping 1768.bmp: No associated .xml file found.
# 1769.bmp
# Skipping 1769.bmp: No associated .xml file found.
# 177.bmp
# Skipping 177.bmp: No associated .xml file found.
# 1770.bmp
# Skipping 1770.bmp: No associated .xml file found.
# 1771.bmp
# Skipping 1771.bmp: No associated .xml file found.
# 1772.bmp
# Skipping 1772.bmp: No associated .xml file found.
# 1773.bmp
# Skipping 1773.bmp: No associated .xml file found.
# 1774.bmp
# 1774.xml
# 1775.bmp
# ...
# 728.bmp
# Skipping 728.bmp: No associated .xml file found.
# 729.bmp
# Skipping 729.bmp: No associated .xml file found.
# 73.bmp
# Skipping 73.bmp: No associated .xml file found.
# 730.bmp
# Skipping 730.bmp: No associated .xml file found.
# 731.bmp
# Skipping 731.bmp: No associated .xml file found.
# 732.bmp
# Skipping 732.bmp: No associated .xml file found.
# 733.bmp
# Skipping 733.bmp: No associated .xml file found.
# 734.bmp
# Skipping 734.bmp: No associated .xml file found.
# 735.bmp
# Skipping 735.bmp: No associated .xml file found.
# 736.bmp
# Skipping 736.bmp: No associated .xml file found.
# 737.bmp
# Skipping 737.bmp: No associated .xml file found.
# 738.bmp
# Skipping 738.bmp: No associated .xml file found.
# 739.bmp
# Skipping 739.bmp: No associated .xml file found.
# 74.bmp
# Skipping 74.bmp: No associated .xml file found.
# 740.bmp
# Skipping 740.bmp: No associated .xml file found.
# 741.bmp
# Skipping 741.bmp: No associated .xml file found.
# 742.bmp
# Skipping 742.bmp: No associated .xml file found.
# 743.bmp
# Skipping 743.bmp: No associated .xml file found.
# 744.bmp
# Skipping 744.bmp: No associated .xml file found.
# 745.bmp
# Skipping 745.bmp: No associated .xml file found.
# 746.bmp
# Skipping 746.bmp: No associated .xml file found.
# 747.bmp
# Skipping 747.bmp: No associated .xml file found.
# 748.bmp
# Skipping 748.bmp: No associated .xml file found.
# 749.bmp
# Skipping 749.bmp: No associated .xml file found.
# 75.bmp
# 75.xml
# 750.bmp
# Skipping 750.bmp: No associated .xml file found.
# 751.bmp
# Skipping 751.bmp: No associated .xml file found.
# 752.bmp
# Skipping 752.bmp: No associated .xml file found.
# 753.bmp
# Skipping 753.bmp: No associated .xml file found.
# 754.bmp
# Skipping 754.bmp: No associated .xml file found.
# 755.bmp
# Skipping 755.bmp: No associated .xml file found.
# 756.bmp
# Skipping 756.bmp: No associated .xml file found.
# 757.bmp
# Skipping 757.bmp: No associated .xml file found.
# 758.bmp
# Skipping 758.bmp: No associated .xml file found.
# 759.bmp
# Skipping 759.bmp: No associated .xml file found.
# 76.bmp
# Skipping 76.bmp: No associated .xml file found.
# 760.bmp
# Skipping 760.bmp: No associated .xml file found.
# 761.bmp
# Skipping 761.bmp: No associated .xml file found.
# 762.bmp
# Skipping 762.bmp: No associated .xml file found.
# 763.bmp
# Skipping 763.bmp: No associated .xml file found.
# 764.bmp
# Skipping 764.bmp: No associated .xml file found.
# 765.bmp
# Skipping 765.bmp: No associated .xml file found.
# 766.bmp
# Skipping 766.bmp: No associated .xml file found.
# 767.bmp
# Skipping 767.bmp: No associated .xml file found.
# 768.bmp
# Skipping 768.bmp: No associated .xml file found.
# 769.bmp
# Skipping 769.bmp: No associated .xml file found.
# 77.bmp
# Skipping 77.bmp: No associated .xml file found.
# 770.bmp
# Skipping 770.bmp: No associated .xml file found.
# 771.bmp
# Skipping 771.bmp: No associated .xml file found.
# 772.bmp
# Skipping 772.bmp: No associated .xml file found.
# 773.bmp
# Skipping 773.bmp: No associated .xml file found.
# 774.bmp
# Skipping 774.bmp: No associated .xml file found.
# 775.bmp
# Skipping 775.bmp: No associated .xml file found.
# 776.bmp
# Skipping 776.bmp: No associated .xml file found.
# 777.bmp
# Skipping 777.bmp: No associated .xml file found.
# 778.bmp
# Skipping 778.bmp: No associated .xml file found.
# 779.bmp
# Skipping 779.bmp: No associated .xml file found.
# 78.bmp
# Skipping 78.bmp: No associated .xml file found.
# 780.bmp
# Skipping 780.bmp: No associated .xml file found.
# 781.bmp
# Skipping 781.bmp: No associated .xml file found.
# 782.bmp
# Skipping 782.bmp: No associated .xml file found.
# 783.bmp
# Skipping 783.bmp: No associated .xml file found.
# 784.bmp
# Skipping 784.bmp: No associated .xml file found.
# 785.bmp
# Skipping 785.bmp: No associated .xml file found.
# 786.bmp
# Skipping 786.bmp: No associated .xml file found.
# 787.bmp
# Skipping 787.bmp: No associated .xml file found.
# 788.bmp
# Skipping 788.bmp: No associated .xml file found.
# 789.bmp
# Skipping 789.bmp: No associated .xml file found.
# 79.bmp
# 79.xml
# 790.bmp
# Skipping 790.bmp: No associated .xml file found.
# 791.bmp
# Skipping 791.bmp: No associated .xml file found.
# 792.bmp
# Skipping 792.bmp: No associated .xml file found.
# 793.bmp
# Skipping 793.bmp: No associated .xml file found.
# 794.bmp
# Skipping 794.bmp: No associated .xml file found.
# 795.bmp
# Skipping 795.bmp: No associated .xml file found.
# 796.bmp
# Skipping 796.bmp: No associated .xml file found.
# 797.bmp
# Skipping 797.bmp: No associated .xml file found.
# 798.bmp
# Skipping 798.bmp: No associated .xml file found.
# 799.bmp
# Skipping 799.bmp: No associated .xml file found.
# 8.bmp
# Skipping 8.bmp: No associated .xml file found.
# 80.bmp
# Skipping 80.bmp: No associated .xml file found.
# 800.bmp
# Skipping 800.bmp: No associated .xml file found.
# 801.bmp
# Skipping 801.bmp: No associated .xml file found.
# 802.bmp
# Skipping 802.bmp: No associated .xml file found.
# 803.bmp
# Skipping 803.bmp: No associated .xml file found.
# 804.bmp
# Skipping 804.bmp: No associated .xml file found.
# 805.bmp
# Skipping 805.bmp: No associated .xml file found.
# 806.bmp
# Skipping 806.bmp: No associated .xml file found.
# 807.bmp
# Skipping 807.bmp: No associated .xml file found.
# 808.bmp
# Skipping 808.bmp: No associated .xml file found.
# 809.bmp
# Skipping 809.bmp: No associated .xml file found.
# 81.bmp
# Skipping 81.bmp: No associated .xml file found.
# 810.bmp
# Skipping 810.bmp: No associated .xml file found.
# 811.bmp
# Skipping 811.bmp: No associated .xml file found.
# 812.bmp
# Skipping 812.bmp: No associated .xml file found.
# 813.bmp
# Skipping 813.bmp: No associated .xml file found.
# 814.bmp
# Skipping 814.bmp: No associated .xml file found.
# 815.bmp
# Skipping 815.bmp: No associated .xml file found.
# 816.bmp
# Skipping 816.bmp: No associated .xml file found.
# 817.bmp
# Skipping 817.bmp: No associated .xml file found.
# 818.bmp
# Skipping 818.bmp: No associated .xml file found.
# 819.bmp
# Skipping 819.bmp: No associated .xml file found.
# 82.bmp
# Skipping 82.bmp: No associated .xml file found.
# 820.bmp
# Skipping 820.bmp: No associated .xml file found.
# 821.bmp
# Skipping 821.bmp: No associated .xml file found.
# 822.bmp
# Skipping 822.bmp: No associated .xml file found.
# 823.bmp
# Skipping 823.bmp: No associated .xml file found.
# 824.bmp
# Skipping 824.bmp: No associated .xml file found.
# 825.bmp
# Skipping 825.bmp: No associated .xml file found.
# 826.bmp
# Skipping 826.bmp: No associated .xml file found.
# 827.bmp
# Skipping 827.bmp: No associated .xml file found.
# 828.bmp
# Skipping 828.bmp: No associated .xml file found.
# 829.bmp
# Skipping 829.bmp: No associated .xml file found.
# 83.bmp
# Skipping 83.bmp: No associated .xml file found.
# 830.bmp
# Skipping 830.bmp: No associated .xml file found.
# 831.bmp
# Skipping 831.bmp: No associated .xml file found.
# 832.bmp
# Skipping 832.bmp: No associated .xml file found.
# 833.bmp
# Skipping 833.bmp: No associated .xml file found.
# 834.bmp
# Skipping 834.bmp: No associated .xml file found.
# 835.bmp
# Skipping 835.bmp: No associated .xml file found.
# 836.bmp
# Skipping 836.bmp: No associated .xml file found.
# 837.bmp
# Skipping 837.bmp: No associated .xml file found.
# 838.bmp
# Skipping 838.bmp: No associated .xml file found.
# 839.bmp
# Skipping 839.bmp: No associated .xml file found.
# 84.bmp
# Skipping 84.bmp: No associated .xml file found.
# 840.bmp
# Skipping 840.bmp: No associated .xml file found.
# 841.bmp
# Skipping 841.bmp: No associated .xml file found.
# 842.bmp
# Skipping 842.bmp: No associated .xml file found.
# 843.bmp
# Skipping 843.bmp: No associated .xml file found.
# 844.bmp
# Skipping 844.bmp: No associated .xml file found.
# 845.bmp
# Skipping 845.bmp: No associated .xml file found.
# 846.bmp
# Skipping 846.bmp: No associated .xml file found.
# 847.bmp
# Skipping 847.bmp: No associated .xml file found.
# 848.bmp
# Skipping 848.bmp: No associated .xml file found.
# 849.bmp
# Skipping 849.bmp: No associated .xml file found.
# 85.bmp
# 85.xml
# 850.bmp
# Skipping 850.bmp: No associated .xml file found.
# 851.bmp
# Skipping 851.bmp: No associated .xml file found.
# 852.bmp
# Skipping 852.bmp: No associated .xml file found.
# 853.bmp
# Skipping 853.bmp: No associated .xml file found.
# 854.bmp
# Skipping 854.bmp: No associated .xml file found.
# 855.bmp
# 855.xml
# 856.bmp
# Skipping 856.bmp: No associated .xml file found.
# 857.bmp
# Skipping 857.bmp: No associated .xml file found.
# 858.bmp
# Skipping 858.bmp: No associated .xml file found.
# 859.bmp
# Skipping 859.bmp: No associated .xml file found.
# 86.bmp
# Skipping 86.bmp: No associated .xml file found.
# 860.bmp
# Skipping 860.bmp: No associated .xml file found.
# 861.bmp
# 861.xml
# 862.bmp
# Skipping 862.bmp: No associated .xml file found.
# 863.bmp
# Skipping 863.bmp: No associated .xml file found.
# 864.bmp
# Skipping 864.bmp: No associated .xml file found.
# 865.bmp
# Skipping 865.bmp: No associated .xml file found.
# 866.bmp
# Skipping 866.bmp: No associated .xml file found.
# 867.bmp
# 867.xml
# 868.bmp
# 868.xml
# 869.bmp
# Skipping 869.bmp: No associated .xml file found.
# 87.bmp
# Skipping 87.bmp: No associated .xml file found.
# 870.bmp
# Skipping 870.bmp: No associated .xml file found.
# 871.bmp
# Skipping 871.bmp: No associated .xml file found.
# 872.bmp
# Skipping 872.bmp: No associated .xml file found.
# 873.bmp
# Skipping 873.bmp: No associated .xml file found.
# 874.bmp
# Skipping 874.bmp: No associated .xml file found.
# 875.bmp
# Skipping 875.bmp: No associated .xml file found.
# 876.bmp
# Skipping 876.bmp: No associated .xml file found.
# 877.bmp
# Skipping 877.bmp: No associated .xml file found.
# 878.bmp
# Skipping 878.bmp: No associated .xml file found.
# 879.bmp
# Skipping 879.bmp: No associated .xml file found.
# 88.bmp
# Skipping 88.bmp: No associated .xml file found.
# 880.bmp
# Skipping 880.bmp: No associated .xml file found.
# 881.bmp
# Skipping 881.bmp: No associated .xml file found.
# 882.bmp
# Skipping 882.bmp: No associated .xml file found.
# 883.bmp
# Skipping 883.bmp: No associated .xml file found.
# 884.bmp
# Skipping 884.bmp: No associated .xml file found.
# 885.bmp
# Skipping 885.bmp: No associated .xml file found.
# 886.bmp
# Skipping 886.bmp: No associated .xml file found.
# 887.bmp
# Skipping 887.bmp: No associated .xml file found.
# 888.bmp
# Skipping 888.bmp: No associated .xml file found.
# 889.bmp
# Skipping 889.bmp: No associated .xml file found.
# 89.bmp
# Skipping 89.bmp: No associated .xml file found.
# 890.bmp
# Skipping 890.bmp: No associated .xml file found.
# 891.bmp
# Skipping 891.bmp: No associated .xml file found.
# 892.bmp
# Skipping 892.bmp: No associated .xml file found.
# 893.bmp
# Skipping 893.bmp: No associated .xml file found.
# 894.bmp
# Skipping 894.bmp: No associated .xml file found.
# 895.bmp
# Skipping 895.bmp: No associated .xml file found.
# 896.bmp
# Skipping 896.bmp: No associated .xml file found.
# 897.bmp
# Skipping 897.bmp: No associated .xml file found.
# 898.bmp
# Skipping 898.bmp: No associated .xml file found.
# 899.bmp
# Skipping 899.bmp: No associated .xml file found.
# 9.bmp
# Skipping 9.bmp: No associated .xml file found.
# 90.bmp
# Skipping 90.bmp: No associated .xml file found.
# 900.bmp
# Skipping 900.bmp: No associated .xml file found.
# 901.bmp
# Skipping 901.bmp: No associated .xml file found.
# 902.bmp
# Skipping 902.bmp: No associated .xml file found.
# 903.bmp
# Skipping 903.bmp: No associated .xml file found.
# 904.bmp
# Skipping 904.bmp: No associated .xml file found.
# 905.bmp
# Skipping 905.bmp: No associated .xml file found.
# 906.bmp
# Skipping 906.bmp: No associated .xml file found.
# 907.bmp
# Skipping 907.bmp: No associated .xml file found.
# 908.bmp
# Skipping 908.bmp: No associated .xml file found.
# 909.bmp
# Skipping 909.bmp: No associated .xml file found.
# 91.bmp
# Skipping 91.bmp: No associated .xml file found.
# 910.bmp
# Skipping 910.bmp: No associated .xml file found.
# 911.bmp
# Skipping 911.bmp: No associated .xml file found.
# 912.bmp
# Skipping 912.bmp: No associated .xml file found.
# 913.bmp
# Skipping 913.bmp: No associated .xml file found.
# 914.bmp
# Skipping 914.bmp: No associated .xml file found.
# 915.bmp
# Skipping 915.bmp: No associated .xml file found.
# 916.bmp
# Skipping 916.bmp: No associated .xml file found.
# 917.bmp
# Skipping 917.bmp: No associated .xml file found.
# 918.bmp
# 918.xml
# 919.bmp
# 919.xml
# 92.bmp
# Skipping 92.bmp: No associated .xml file found.
# 920.bmp
# Skipping 920.bmp: No associated .xml file found.
# 921.bmp
# 921.xml
# 922.bmp
# Skipping 922.bmp: No associated .xml file found.
# 923.bmp
# 923.xml
# 924.bmp
# 924.xml
# 925.bmp
# 925.xml
# 926.bmp
# 926.xml
# 927.bmp
# Skipping 927.bmp: No associated .xml file found.
# 928.bmp
# 928.xml
# 929.bmp
# 929.xml
# 93.bmp
# Skipping 93.bmp: No associated .xml file found.
# 930.bmp
# Skipping 930.bmp: No associated .xml file found.
# 931.bmp
# Skipping 931.bmp: No associated .xml file found.
# 932.bmp
# Skipping 932.bmp: No associated .xml file found.
# 933.bmp
# Skipping 933.bmp: No associated .xml file found.
# 934.bmp
# Skipping 934.bmp: No associated .xml file found.
# 935.bmp
# Skipping 935.bmp: No associated .xml file found.
# 936.bmp
# Skipping 936.bmp: No associated .xml file found.
# 937.bmp
# Skipping 937.bmp: No associated .xml file found.
# 938.bmp
# Skipping 938.bmp: No associated .xml file found.
# 939.bmp
# Skipping 939.bmp: No associated .xml file found.
# 94.bmp
# Skipping 94.bmp: No associated .xml file found.
# 940.bmp
# Skipping 940.bmp: No associated .xml file found.
# 941.bmp
# 941.xml
# 942.bmp
# Skipping 942.bmp: No associated .xml file found.
# 943.bmp
# Skipping 943.bmp: No associated .xml file found.
# 944.bmp
# Skipping 944.bmp: No associated .xml file found.
# 945.bmp
# Skipping 945.bmp: No associated .xml file found.
# 946.bmp
# Skipping 946.bmp: No associated .xml file found.
# 947.bmp
# Skipping 947.bmp: No associated .xml file found.
# 948.bmp
# Skipping 948.bmp: No associated .xml file found.
# 949.bmp
# Skipping 949.bmp: No associated .xml file found.
# 95.bmp
# Skipping 95.bmp: No associated .xml file found.
# 950.bmp
# Skipping 950.bmp: No associated .xml file found.
# 951.bmp
# 951.xml
# 952.bmp
# Skipping 952.bmp: No associated .xml file found.
# 953.bmp
# Skipping 953.bmp: No associated .xml file found.
# 954.bmp
# 954.xml
# 955.bmp
# Skipping 955.bmp: No associated .xml file found.
# 956.bmp
# Skipping 956.bmp: No associated .xml file found.
# 957.bmp
# Skipping 957.bmp: No associated .xml file found.
# 958.bmp
# Skipping 958.bmp: No associated .xml file found.
# 959.bmp
# Skipping 959.bmp: No associated .xml file found.
# 96.bmp
# 96.xml
# 960.bmp
# 960.xml
# 961.bmp
# Skipping 961.bmp: No associated .xml file found.
# 962.bmp
# 962.xml
# 963.bmp
# Skipping 963.bmp: No associated .xml file found.
# 964.bmp
# Skipping 964.bmp: No associated .xml file found.
# 965.bmp
# Skipping 965.bmp: No associated .xml file found.
# 966.bmp
# Skipping 966.bmp: No associated .xml file found.
# 967.bmp
# Skipping 967.bmp: No associated .xml file found.
# 968.bmp
# Skipping 968.bmp: No associated .xml file found.
# 969.bmp
# Skipping 969.bmp: No associated .xml file found.
# 97.bmp
# Skipping 97.bmp: No associated .xml file found.
# 970.bmp
# Skipping 970.bmp: No associated .xml file found.
# 971.bmp
# Skipping 971.bmp: No associated .xml file found.
# 972.bmp
# Skipping 972.bmp: No associated .xml file found.
# 973.bmp
# Skipping 973.bmp: No associated .xml file found.
# 974.bmp
# Skipping 974.bmp: No associated .xml file found.
# 975.bmp
# Skipping 975.bmp: No associated .xml file found.
# 976.bmp
# 976.xml
# 977.bmp
# Skipping 977.bmp: No associated .xml file found.
# 978.bmp
# 978.xml
# 979.bmp
# Skipping 979.bmp: No associated .xml file found.
# 98.bmp
# Skipping 98.bmp: No associated .xml file found.
# 980.bmp
# Skipping 980.bmp: No associated .xml file found.
# 981.bmp
# Skipping 981.bmp: No associated .xml file found.
# 982.bmp
# Skipping 982.bmp: No associated .xml file found.
# 983.bmp
# Skipping 983.bmp: No associated .xml file found.
# 984.bmp
# Skipping 984.bmp: No associated .xml file found.
# 985.bmp
# Skipping 985.bmp: No associated .xml file found.
# 986.bmp
# 986.xml
# 987.bmp
# 987.xml
# 988.bmp
# 988.xml
# 989.bmp
# Skipping 989.bmp: No associated .xml file found.
# 99.bmp
# Skipping 99.bmp: No associated .xml file found.
# 990.bmp
# Skipping 990.bmp: No associated .xml file found.
# 991.bmp
# Skipping 991.bmp: No associated .xml file found.
# 992.bmp
# 992.xml
# 993.bmp
# Skipping 993.bmp: No associated .xml file found.
# 994.bmp
# Skipping 994.bmp: No associated .xml file found.
# 995.bmp
# Skipping 995.bmp: No associated .xml file found.
# 996.bmp
# Skipping 996.bmp: No associated .xml file found.
# 997.bmp
# Skipping 997.bmp: No associated .xml file found.
# 998.bmp
# Skipping 998.bmp: No associated .xml file found.
# 999.bmp
# Skipping 999.bmp: No associated .xml file found.
# Defect plots generated successfully!

# %%
df_f
# Out:
#     image_path    h    w  c   defect    xmin_n    ymin_n    xmax_n    ymax_n
# 0     1001.bmp  256  256  3  scratch  0.003906  0.152344  0.066406  0.242188
# 1     1009.bmp  256  256  3  scratch  0.003906  0.003906  0.121094  0.316406
# 2     1009.bmp  256  256  3  scratch  0.121094  0.664062  0.230469  1.000000
# 3     1009.bmp  256  256  3  scratch  0.062500  0.648438  0.113281  0.746094
# 4     1009.bmp  256  256  3  scratch  0.003906  0.671875  0.042969  0.750000
# ..         ...  ...  ... ..      ...       ...       ...       ...       ...
# 523    987.bmp  256  256  3    paint  0.148438  0.042969  0.195312  0.101562
# 524    987.bmp  256  256  3    paint  0.003906  0.031250  0.074219  0.253906
# 525    988.bmp  256  256  3    paint  0.058594  0.902344  0.285156  1.000000
# 526    988.bmp  256  256  3  scratch  0.859375  0.761719  1.000000  1.000000
# 527    992.bmp  256  256  3  scratch  0.402344  0.054688  0.734375  0.593750
#
# [528 rows x 9 columns]

# %%
# for each image, grab associated 

for index, row in df_f.iterrows():
    defect = row['defect']
    xmin = row['xmin_n']
    xmax = row['xmax_n']
    ymin = row['ymin_n']
    ymax = row['ymax_n']
    #print(f"Defect: {defect}, Xmin: {xmin}")

    print(type(defect))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
